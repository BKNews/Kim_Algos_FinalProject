# %% [markdown]
# # Reading Consumer Financial Protection Bureau’s consumer complaint data

# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", 200)
pd.set_option("display.max_colwidth", 200)
# Out:
# /Users/lisakim/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
# !ls
# Out:
# -
# Algorithms
# ArticlesToRemember
# BogyungKim_Finding&InterviewingSources.docx
# CV, Resume
# Cisco AnyConnect Secure Mobility Client
# ConsumerComplaint
# ConsumerCreditRating
# DD_FinalProject
# Data_Questions.docx
# GitHub Desktop.app
# Google Chrome
# Homeownership
# Ideas
# Insurance
# Insurance_ContactList.docx
# J-School
# JeremiaVersion_VapeShops.ipynb
# JobOpp..docx
# KakaoTalk
# Kim_AlgosFinalProject.ipynb
# Little Geocoder.app
# Master's Project
# Motor_Vehicle_Collisions_-_Crashes.csv
# Narrative Writing
# NatureOfSuit.png
# OpenRefine
# PicsFromPhone2021
# Pitch1_PPP
# Pitch3_CityFundedShelters
# Pitch3_NYC_PE
# Pitch4_Conviction
# Pitch5_311Reports
# Pithch4_Arrests2020
# Postgres
# Project_Template.docx
# Python Wrangler
# QGIS
# Research_Highlights.docx
# Soma's Class
# Visual Studio Code.app
# VisualStudio
# Week 09- inclass-wine.ipynb
# WhatsApp
# Writing With Data
# fl
# library search
# m
# online reporting
# source list.docx
# tableau
# timemanager
# ~$-GYUNG_writing center.MikeNotes.docx
# ~$dio workshop_script_BogyungKim.docx
# ~$eelancing email.docx
# ~$estions for Chris Hearsay.docx
# ~$gyungKim_MondialHomwork.docx
# ~$gyungKim_experts.docx
# ~$m_enterprise1_rough1.docx
# ~$saKim_lisakim0425@gmail.com.docx
# 종군위안부

# %%
import os
os.chdir("ConsumerComplaint")

# %%
# !ls
# Out:
# CC_Forbearance.csv
# CC_MORTGAGE.docx
# CC_STUDENTLOANS.docx
# ConsumerComplaint.ipynb
# ConsumerComplaintData2020.csv
# ConsumerComplaintData2020_new.csv
# ConsumerComplaintData_ProbCompInvest.csv
# Original_complaints.csv
# StudentLoan.csv

# %%
df = pd.read_csv("ConsumerComplaintData2020.csv")

# %%
df.shape
# Out:
# (5708, 18)

# %% [markdown]
# ## Cleaning df

# %%
# The bureau replaced Xs for the names of companies other the ones each consumer filed a complaint againt.
# So I'll removed the Xs in the 'Consumer complaint narrative' column.

# %%
df['Consumer complaint narrative'] = df['Consumer complaint narrative'].str.replace('XXXX', '', regex=False)

# %%
df.head(2)
# Out:
#   Date received  \
# 0    2020-03-20
# 1    2020-01-16
#
#                                                                         Product  \
# 0  Credit reporting, credit repair services, or other personal consumer reports
# 1  Credit reporting, credit repair services, or other personal consumer reports
#
#         Sub-product  \
# 0  Credit reporting
# 1  Credit reporting
#
#                                                                               Issue  \
# 0  Problem with a credit reporting company's investigation into an existing problem
# 1                                              Incorrect information on your report
#
#                                                  Sub-issue  \
# 0  Their investigation did not fix an error on your report
# 1                      Information belongs to someone else
#
#                                                                                                                                                                               Consumer complaint narrative  \
# 0            , NY  Dear  , The reason why I am contacting you is to discuss a couple of late payments that greatly affected my current credit score. Through my four leases with  my payments have alwa...
# 1  PLEASE REMOVE THE DISPUTED ACCOUNTS OFF MY CREDIT REPORT. THE TRANSACTIONS ARE INACCURATE AND I WOULD LIKE THOSE ACCOUNTS OFF MY FILE. THEY HAVE BEEN HINDERING MY CREDIT AND HAVE CAUSED HARM OFF A...
#
#   Company public response        Company State ZIP code Tags  \
# 0                     NaN  EQUIFAX, INC.    NY    143XX  NaN
# 1                     NaN  EQUIFAX, INC.    NY    115XX  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web           2020-03-20
# 1           Consent provided           Web           2020-01-16
#
#       Company response to consumer Timely response?  Consumer disputed?  \
# 0          Closed with explanation              Yes                 NaN
# 1  Closed with non-monetary relief              Yes                 NaN
#
#    Complaint ID
# 0       3574222
# 1       3499342

# %%
df['Sub-issue'].value_counts()
# Out:
# Information belongs to someone else                                                      1964
# Their investigation did not fix an error on your report                                   957
# Account status incorrect                                                                  416
# Investigation took more than 30 days                                                      409
# Credit inquiries on your report that you don't recognize                                  364
# Account information incorrect                                                             363
# Was not notified of investigation status or results                                       280
# Problem getting your free annual credit report                                            138
# Difficulty submitting a dispute or getting information about a dispute over the phone     120
# Old information reappears or never goes away                                              111
# Personal information incorrect                                                             90
# Reporting company used your report improperly                                              81
# Problem with personal statement of dispute                                                 74
# Information is missing that should be on the report                                        68
# Public record information inaccurate                                                       61
# Other problem getting your report or credit score                                          56
# Billing dispute for services                                                               25
# Problem canceling credit monitoring or identify theft protection service                    9
# Information is incorrect                                                                    6
# Didn't receive services that were advertised                                                4
# Problem with product or service terms changing                                              3
# Information that should be on the report is missing                                         3
# Received unwanted marketing or advertising                                                  2
# Name: Sub-issue, dtype: int64

# %% [markdown]
# # Looking for a correlation between complaint narratives and the issues consumers raised

# %% [markdown]
# ### Of the issues, I'm going to examine 'Account status incorrect' & 'Investigation took more than 30 days'

# %%
complaint_df = df[df['Sub-issue'].isin(['Account status incorrect', 'Investigation took more than 30 days'])].dropna(subset=['Consumer complaint narrative'])
complaint_df['Sub-issue'].value_counts()
# Out:
# Account status incorrect                416
# Investigation took more than 30 days    409
# Name: Sub-issue, dtype: int64

# %%
complaint_df['is_AccountStatusIncorrect'] =  (df['Sub-issue'] == 'Account status incorrect').astype(int)
complaint_df['is_AccountStatusIncorrect'].value_counts()
# Out:
# 1    416
# 0    409
# Name: is_AccountStatusIncorrect, dtype: int64

# %%
pd.DataFrame({
    'late': complaint_df['Consumer complaint narrative'].str.contains("late", na=False).astype(int),
    'wrong': complaint_df['Consumer complaint narrative'].str.contains("wrong", na=False).astype(int),
    'inaccurate': complaint_df['Consumer complaint narrative'].str.contains("inaccurate", na=False).astype(int),
})
# Out:
#       late  wrong  inaccurate
# 7        0      0           0
# 22       0      0           0
# 28       1      0           0
# 30       0      0           0
# 34       0      0           0
# ...    ...    ...         ...
# 5672     1      0           0
# 5673     0      1           0
# 5695     0      0           0
# 5700     0      0           0
# 5701     0      0           0
#
# [825 rows x 3 columns]

# %% [markdown]
# # TfidfVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english', min_df=100)

matrix = vectorizer.fit_transform(complaint_df['Consumer complaint narrative'])

words_df = pd.DataFrame(matrix.toarray(),
                        columns=vectorizer.get_feature_names())
words_df
# Out:
#            00      2020        30   account  accounts  agencies   bureaus  \
# 0    0.000000  0.180463  0.000000  0.000000  0.000000  0.196769  0.161291
# 1    0.000000  0.000000  0.000000  0.216426  0.000000  0.000000  0.000000
# 2    0.086424  0.000000  0.000000  0.560760  0.072068  0.000000  0.000000
# 3    0.000000  0.000000  0.000000  0.205536  0.264152  0.000000  0.000000
# 4    0.000000  0.000000  0.000000  0.458510  0.000000  0.000000  0.000000
# ..        ...       ...       ...       ...       ...       ...       ...
# 820  0.244991  0.000000  0.000000  0.000000  0.000000  0.000000  0.094385
# 821  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 822  0.000000  0.000000  0.000000  0.153739  0.000000  0.000000  0.000000
# 823  0.000000  0.271265  0.371875  0.000000  0.000000  0.147888  0.121223
# 824  0.000000  0.271265  0.371875  0.000000  0.000000  0.147888  0.121223
#
#      closed   company    credit      date       day      days       did  \
# 0       0.0  0.000000  0.240092  0.000000  0.000000  0.000000  0.000000
# 1       0.0  0.000000  0.127526  0.000000  0.000000  0.000000  0.335389
# 2       0.0  0.087873  0.033042  0.000000  0.000000  0.000000  0.173799
# 3       0.0  0.000000  0.121109  0.000000  0.000000  0.000000  0.000000
# 4       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# ..      ...       ...       ...       ...       ...       ...       ...
# 820     0.0  0.000000  0.093666  0.000000  0.000000  0.000000  0.000000
# 821     0.0  0.276469  0.415832  0.000000  0.000000  0.000000  0.000000
# 822     0.0  0.000000  0.181177  0.252541  0.000000  0.000000  0.000000
# 823     0.0  0.000000  0.180448  0.000000  0.336409  0.105479  0.000000
# 824     0.0  0.000000  0.180448  0.000000  0.336409  0.105479  0.000000
#
#       dispute     filed      help  inaccurate  incorrect  information  \
# 0    0.312301  0.408723  0.000000    0.177449        0.0     0.147574
# 1    0.000000  0.000000  0.000000    0.000000        0.0     0.235154
# 2    0.000000  0.000000  0.000000    0.000000        0.0     0.060929
# 3    0.000000  0.000000  0.000000    0.000000        0.0     0.000000
# 4    0.527139  0.000000  0.000000    0.000000        0.0     0.249093
# ..        ...       ...       ...         ...        ...          ...
# 820  0.000000  0.000000  0.000000    0.000000        0.0     0.000000
# 821  0.000000  0.000000  0.284587    0.000000        0.0     0.000000
# 822  0.000000  0.000000  0.000000    0.000000        0.0     0.000000
# 823  0.234720  0.307189  0.000000    0.133367        0.0     0.110914
# 824  0.234720  0.307189  0.000000    0.133367        0.0     0.110914
#
#      investigation     items      late    letter  letters      loan  negative  \
# 0         0.191663  0.000000  0.000000  0.000000      0.0  0.000000       0.0
# 1         0.000000  0.000000  0.000000  0.303988      0.0  0.000000       0.0
# 2         0.000000  0.000000  0.000000  0.000000      0.0  0.089919       0.0
# 3         0.000000  0.282187  0.000000  0.000000      0.0  0.000000       0.0
# 4         0.000000  0.000000  0.000000  0.322008      0.0  0.000000       0.0
# ..             ...       ...       ...       ...      ...       ...       ...
# 820       0.000000  0.000000  0.106285  0.000000      0.0  0.000000       0.0
# 821       0.000000  0.000000  0.000000  0.000000      0.0  0.000000       0.0
# 822       0.000000  0.000000  0.000000  0.000000      0.0  0.493046       0.0
# 823       0.144051  0.000000  0.000000  0.000000      0.0  0.000000       0.0
# 824       0.144051  0.000000  0.000000  0.000000      0.0  0.000000       0.0
#
#      paid   payment  payments   receive  received   regards  remove  removed  \
# 0     0.0  0.000000  0.000000  0.224500  0.145878  0.431787     0.0      0.0
# 1     0.0  0.000000  0.000000  0.357733  0.000000  0.000000     0.0      0.0
# 2     0.0  0.000000  0.000000  0.000000  0.060228  0.000000     0.0      0.0
# 3     0.0  0.000000  0.000000  0.000000  0.441510  0.000000     0.0      0.0
# 4     0.0  0.000000  0.000000  0.000000  0.000000  0.000000     0.0      0.0
# ..    ...       ...       ...       ...       ...       ...     ...      ...
# 820   0.0  0.528022  0.000000  0.000000  0.000000  0.000000     0.0      0.0
# 821   0.0  0.000000  0.518844  0.000000  0.000000  0.000000     0.0      0.0
# 822   0.0  0.000000  0.226059  0.254117  0.000000  0.000000     0.0      0.0
# 823   0.0  0.000000  0.000000  0.168730  0.109639  0.324523     0.0      0.0
# 824   0.0  0.000000  0.000000  0.168730  0.109639  0.324523     0.0      0.0
#
#        report  reported  reporting   reports   request  respond  response  \
# 0    0.000000  0.000000   0.262733  0.217791  0.000000      0.0  0.000000
# 1    0.000000  0.000000   0.000000  0.000000  0.000000      0.0  0.000000
# 2    0.042440  0.000000   0.000000  0.000000  0.000000      0.0  0.000000
# 3    0.311109  0.000000   0.000000  0.000000  0.000000      0.0  0.630115
# 4    0.347010  0.000000   0.000000  0.000000  0.000000      0.0  0.000000
# ..        ...       ...        ...       ...       ...      ...       ...
# 820  0.060153  0.111122   0.000000  0.000000  0.127825      0.0  0.000000
# 821  0.000000  0.246666   0.170642  0.000000  0.000000      0.0  0.000000
# 822  0.000000  0.214943   0.148697  0.000000  0.000000      0.0  0.000000
# 823  0.000000  0.000000   0.197465  0.163688  0.000000      0.0  0.156475
# 824  0.000000  0.000000   0.197465  0.163688  0.000000      0.0  0.156475
#
#       results     score      sent   showing      time        xx
# 0    0.214043  0.000000  0.000000  0.000000  0.000000  0.264710
# 1    0.000000  0.000000  0.582595  0.351202  0.293212  0.000000
# 2    0.000000  0.000000  0.000000  0.090996  0.151943  0.765031
# 3    0.323909  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.361287  0.000000  0.308565  0.000000  0.000000  0.000000
# ..        ...       ...       ...       ...       ...       ...
# 820  0.000000  0.000000  0.000000  0.000000  0.000000  0.774524
# 821  0.000000  0.286297  0.000000  0.000000  0.478048  0.000000
# 822  0.000000  0.249477  0.000000  0.000000  0.624852  0.000000
# 823  0.000000  0.000000  0.000000  0.000000  0.000000  0.397903
# 824  0.000000  0.000000  0.000000  0.000000  0.000000  0.397903
#
# [825 rows x 48 columns]

# %%
# features
X = words_df
# labels
y = complaint_df['is_AccountStatusIncorrect']

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators=10)
clf.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
clf.score(X, y)
# Out:
# 0.9987878787878788

# %%
from sklearn.metrics import confusion_matrix

y_true = y
y_pred = clf.predict(X)
matrix = confusion_matrix(y_true, y_pred)

label_names = pd.Series(['AccountStatusIncorrect', 'InvestgationLonger30Days'])

pd.DataFrame(matrix,
     columns='Predicted ' + label_names,
     index='Is ' + label_names)
# Out:
#                              Predicted AccountStatusIncorrect  \
# Is AccountStatusIncorrect                                 409
# Is InvestgationLonger30Days                                 1
#
#                              Predicted InvestgationLonger30Days
# Is AccountStatusIncorrect                                     0
# Is InvestgationLonger30Days                                 415

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
clf.score(X_test, y_test)
# Out:
# 0.9468599033816425

# %%
from sklearn.metrics import confusion_matrix

y_true = y_test
y_pred = clf.predict(X_test)
matrix = confusion_matrix(y_true, y_pred)

label_names = pd.Series(['AccountStatusIncorrect', 'InvestgationLonger30Days'])

pd.DataFrame(matrix,
     columns='Predicted ' + label_names,
     index='Is ' + label_names)
# Out:
#                              Predicted AccountStatusIncorrect  \
# Is AccountStatusIncorrect                                  88
# Is InvestgationLonger30Days                                 3
#
#                              Predicted InvestgationLonger30Days
# Is AccountStatusIncorrect                                     8
# Is InvestgationLonger30Days                                 108

# %% [markdown]
# # LinearSVC

# %%
from sklearn.svm import LinearSVC

clf = LinearSVC()

clf.fit(X_train, y_train)
# Out:
# LinearSVC()

# %%
clf.score(X_test, y_test)
# Out:
# 0.9178743961352657

# %%
from sklearn.metrics import confusion_matrix

y_true = y_test
y_pred = clf.predict(X_test)
matrix = confusion_matrix(y_true, y_pred)

label_names = pd.Series(['AccountStatusIncorrect', 'InvestgationLonger30Days'])

pd.DataFrame(matrix,
     columns='Predicted ' + label_names,
     index='Is ' + label_names)
# Out:
#                              Predicted AccountStatusIncorrect  \
# Is AccountStatusIncorrect                                  87
# Is InvestgationLonger30Days                                 8
#
#                              Predicted InvestgationLonger30Days
# Is AccountStatusIncorrect                                     9
# Is InvestgationLonger30Days                                 103

# %%
import eli5

feature_names = list(words_df.columns)
eli5.show_weights(clf, feature_names=feature_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=1
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 86.70%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.692
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         loan
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 88.16%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.433
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         late
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.14%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.266
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         paid
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.243
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         remove
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 89.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +1.150
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         reported
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.71%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.861
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         payment
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 91.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.840
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         closed
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.38%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.764
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         company
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(120, 100.00%, 92.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.761
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         did
#     </td>
#
# </tr>
#
#
#             <tr style="background-color: hsl(120, 100.00%, 92.40%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 11 more positive &hellip;</i>
#                 </td>
#             </tr>
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 91.75%); border: none;">
#                 <td colspan="2" style="padding: 0 0.5em 0 0.5em; text-align: center; border: none; white-space: nowrap;">
#                     <i>&hellip; 18 more negative &hellip;</i>
#                 </td>
#             </tr>
#
#
#             <tr style="background-color: hsl(0, 100.00%, 91.75%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.855
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         letter
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 91.28%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.925
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         day
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.85%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.150
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         negative
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.46%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.213
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         bureaus
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 89.10%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.274
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         response
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 88.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.364
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         items
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 88.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.392
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         2020
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 86.15%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.792
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         results
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 85.41%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -1.931
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         date
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 84.40%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -2.125
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         days
#     </td>
#
# </tr>
#
#             <tr style="background-color: hsl(0, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -3.030
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         letters
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>

# %% [markdown]
# # ExtraTreeClassifier

# %%
from sklearn.tree import ExtraTreeClassifier

clf = ExtraTreeClassifier()

clf.fit(X_train, y_train)
# Out:
# ExtraTreeClassifier()

# %%
clf.score(X_test, y_test)
# Out:
# 0.9178743961352657

# %%
from sklearn.metrics import confusion_matrix

y_true = y_test
y_pred = clf.predict(X_test)
matrix = confusion_matrix(y_true, y_pred)

label_names = pd.Series(['AccountStatusIncorrect', 'InvestgationLonger30Days'])

pd.DataFrame(matrix,
     columns='Predicted ' + label_names,
     index='Is ' + label_names)
# Out:
#                              Predicted AccountStatusIncorrect  \
# Is AccountStatusIncorrect                                  86
# Is InvestgationLonger30Days                                 7
#
#                              Predicted InvestgationLonger30Days
# Is AccountStatusIncorrect                                    10
# Is InvestgationLonger30Days                                 104

# %% [markdown]
# # ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

clf = ExtraTreesClassifier()

clf.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier()

# %%
clf.score(X_test, y_test)
# Out:
# 0.9516908212560387

# %%
from sklearn.metrics import confusion_matrix

y_true = y_test
y_pred = clf.predict(X_test)
matrix = confusion_matrix(y_true, y_pred)

label_names = pd.Series(['AccountStatusIncorrect', 'InvestgationLonger30Days'])

pd.DataFrame(matrix,
     columns='Predicted ' + label_names,
     index='Is ' + label_names)
# Out:
#                              Predicted AccountStatusIncorrect  \
# Is AccountStatusIncorrect                                  87
# Is InvestgationLonger30Days                                 1
#
#                              Predicted InvestgationLonger30Days
# Is AccountStatusIncorrect                                     9
# Is InvestgationLonger30Days                                 110
